# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('input/wind/processed_sfo_santacruz_20_years.csv')

# %%
def round_to_nearest_45(n):
    return round(n / 45) * 45

def convert_to_int(n):
    return int(n)

# %%
df['datetime'] = pd.to_datetime(df['datetime'])
df['hour'] = df['datetime'].dt.hour
# Impute missing values in 'winddir'
df['winddir'] = df['winddir'].fillna(df['winddir'].mean())


def calculate_hourly_percentiles(data, percentile):
    # Create an empty DataFrame to store percentile values for each hour
    percentile_values = []

    # Loop over each hour
    for hour in range(24):
        # Filter data for the specific hour
        hourly_data = data[data['hour'] == hour]

        # Calculate the Xth percentile for wind speed and wind direction
        wind_speed_percentile = np.percentile(hourly_data['windspeed'], percentile)
        wind_dir_percentile = np.percentile(hourly_data['winddir'], percentile)

        # Append the results to the list
        percentile_values.append({'hour': hour, 'windspeed': wind_speed_percentile, 'winddir': wind_dir_percentile})

    # Convert list to DataFrame
    df = pd.DataFrame(percentile_values)
    df['windspeed'] = df['windspeed'].fillna(0)
    df['winddir'] = df['winddir'].fillna(0)
    df['winddir'] = df['winddir'].apply(round_to_nearest_45)
    df['windspeed'] = df['windspeed'].apply(convert_to_int)     
    return df

# hourly_percentiles = calculate_hourly_percentiles(df, 99)
# hourly_percentiles

# %%
import sqlite3
# Correcting the query with the right column names
query_final = '''
SELECT flight_distance, flight_time, energy_consumption, wind_direction_degrees, wind_magnitude_mph
FROM flight_metrics
'''

conn = sqlite3.connect('input/wind/icrat.sqlite')

# Read the data into a DataFrame with the final query
try:
    df_flight_metrics = pd.read_sql_query(query_final, conn)
    message_final = "Data loaded successfully from the SQLite database."
except Exception as e:
    df_flight_metrics = None
    message_final = str(e)

df_flight_metrics.sort_values(by=['flight_distance', 
                                  'wind_magnitude_mph', 
                                  'wind_direction_degrees'], ascending=True, inplace=True)
df_flight_metrics.reset_index(drop=True, inplace=True)
df_flight_metrics = df_flight_metrics.groupby(['flight_distance', 
                                               'wind_direction_degrees', 
                                               'wind_magnitude_mph']).mean().reset_index()

df_flight_metrics
# Out:
#       flight_distance  wind_direction_degrees  wind_magnitude_mph  \
# 0                  20                       0                   0
# 1                  20                       0                   1
# 2                  20                       0                   2
# 3                  20                       0                   3
# 4                  20                       0                   4
# ...               ...                     ...                 ...
# 1714               60                     360                  36
# 1715               60                     360                  37
# 1716               60                     360                  38
# 1717               60                     360                  39
# 1718               60                     360                  40
#
#       flight_time  energy_consumption
# 0       10.096742           21.779902
# 1       10.075754           21.746685
# 2       10.054998           21.715017
# 3       10.034471           21.684900
# 4       10.014169           21.656342
# ...           ...                 ...
# 1714    20.382043           40.054396
# 1715    20.316793           40.001717
# 1716    20.252147           39.952310
# 1717    20.188095           39.906229
# 1718    20.124630           39.863534
#
# [1719 rows x 5 columns]

# %%
from scipy.spatial.distance import cdist

def match_and_add_flight_metrics(percentile_df, flight_metrics_df):
    results_list = []
    for _, row in percentile_df.iterrows():
        windspeed = row['windspeed']
        winddir = row['winddir']
        distances = cdist([[windspeed, winddir]], flight_metrics_df[['wind_magnitude_mph', 'wind_direction_degrees']].values)
        min_distance_index = distances.argmin()
        closest_match = flight_metrics_df.iloc[min_distance_index][['flight_distance', 'flight_time', 'energy_consumption']]
        results_list.append(closest_match)
    results_df = pd.DataFrame(results_list).reset_index(drop=True)
    results_df['flight_direction'] = 'A-B'

    return pd.concat([percentile_df, results_df], axis=1)

def process_and_match_for_B_A(percentile_df, flight_metrics_df):
    # Adjust the wind direction for 'B-A'
    percentile_df['winddir'] = abs(percentile_df['winddir'] - 180)

    # Use the existing function to match and add flight metrics
    return match_and_add_flight_metrics(percentile_df, flight_metrics_df)


# Specified Percentiles
percentiles = [50, 60, 70, 80, 90, 95, 99, 99.5]

all_results = []  # List to store all result DataFrames

for flight_distance, group_df in df_flight_metrics.groupby('flight_distance'):
    for p in percentiles:
        percentile_df = calculate_hourly_percentiles(df, p)

        # Process for A-B Direction
        ab_results = match_and_add_flight_metrics(percentile_df, group_df)
        ab_results['flight_direction'] = 'A-B'
        ab_results['percentile'] = p
        ab_results['flight_distance'] = flight_distance

        # Process for B-A Direction
        ba_results = process_and_match_for_B_A(percentile_df.copy(), group_df)
        ba_results['flight_direction'] = 'B-A'
        ba_results['percentile'] = p
        ba_results['flight_distance'] = flight_distance

        # Combine A-B and B-A results
        combined_results = pd.concat([ab_results, ba_results])
        all_results.append(combined_results)

# Combine all results into a single DataFrame
final_results_df = pd.concat(all_results).reset_index(drop=True)

# %% [markdown]
# # Starting Albert's Code

# %%
import pandas as pd
import numpy as np 
final_results_df = pd.read_csv('input/wind/optimizer_input.csv')
final_results_df['flight_time'] = final_results_df['flight_time_rounded']
final_results_df['energy_consumption'] = final_results_df['energy_consumption_%']

# %%
ab = final_results_df[final_results_df['flight_direction'] == 'A-B']
ba = final_results_df[final_results_df['flight_direction'] == 'B-A']

# %%
# num_runs = 24
num_runs = 112

percentile_id = ab['percentile'].to_numpy().reshape(num_runs, 24)[:,0]
distance_id = ab['flight_distance'].to_numpy().reshape(num_runs, 24)[:,0]

ab_flight_time = ab['flight_time'].to_numpy().reshape(num_runs, 24)
ba_flight_time = ba['flight_time'].to_numpy().reshape(num_runs, 24)

ab_energy_consumption = ab['energy_consumption'].to_numpy().reshape(num_runs, 24)
ba_energy_consumption = ba['energy_consumption'].to_numpy().reshape(num_runs, 24)

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    # display(ab[ab['flight_distance'] == 20])  # Display the DataFrame in the Jupyter Notebook cell

# %%
params = {}

for i in range(len(ab_flight_time)):
    flight_time = np.zeros((289, 2, 2))
    flight_time[1:289,0,1] = np.repeat(ab_flight_time[i,:],12)
    flight_time[1:289,1,0] = np.repeat(ba_flight_time[i,:],12)

    energy_consumption = np.zeros((289, 2, 2))
    energy_consumption[1:289,0,1] = np.repeat(ab_energy_consumption[i,:],12)
    energy_consumption[1:289,1,0] = np.repeat(ba_energy_consumption[i,:],12)

    run_id = f"dist_{int(distance_id[i])}_per_{int(percentile_id[i]*10)}"
    if run_id not in params:
        params[run_id] = {}
    params[run_id]['flight_time'] = flight_time
    params[run_id]['energy_consumption'] = energy_consumption

# %%
params['dist_20_per_50']['flight_time']

# %%
# import pickle
# with open('input/wind/wind_params_updated.pkl', 'wb') as f:
#     pickle.dump(params, f)

# %%
with open('input/wind/wind_params_updated.pkl', 'rb') as f:
    params = pickle.load(f)

# %% [markdown]
# # Get Wind Results

# %%
import os 
import pandas as pd
import numpy as np
import sqlite3
from model.op import FleetSizeOptimizer
import pickle

# %%
with open('input/wind/wind_params_updated.pkl', 'rb') as f:
    params = pickle.load(f)

# %%
file_list = os.listdir('output/ICRAT_wind/fleet_op_result')
all_files = []
for filename in file_list:
    if filename.endswith('_op_result.txt'):
        all_files.append(filename)
file_names = np.empty(shape=(0, 4))
for i in all_files:
    file_names = np.vstack((file_names, np.array(i.split('_')[:4])))

# %%
conn = sqlite3.connect('wind_variation_result.sqlite')
for i in range(len(all_files)):
    # Load parameters
    run_id = all_files[i].split('_op_result.txt')[0]
    flight_time = params[run_id]['flight_time']
    energy_consumption = params[run_id]['energy_consumption']
    flight_distance = np.array([[0, file_names[i][1]], [file_names[i][1], 0]]).astype(int)

    # Call optimizer class and redner summary
    optimizer = FleetSizeOptimizer(flight_time, energy_consumption, schedule='ICRAT_wind/schedule_1500pax_5min_0125.csv')
    result_path = f'ICRAT_wind/fleet_op_result/{all_files[i]}'
    optimizer.parse_result(result_path)
    optimizer.calculate_aircraft_states()
    summary = optimizer.get_summary_statistics(flight_distance, return_summary=True)

    # Save summary statistics
    line_i = np.array([summary['fleet_size'], summary['pads'][0], summary['pads'][1], summary['number_of_repositioning_flights']])
    summary_statistics = pd.DataFrame(line_i.reshape(1,4), columns=['fleet_size', 'pads_at_SFO', 'pads_at_SJC', 'number_of_repositioning_flights'])
    summary_statistics['id'] = run_id
    summary_statistics.to_sql('op_summary_statistics', conn, if_exists='append', index=False)

    # Save vertisim inputs
    vertisim_input = pd.concat([optimizer.specificc, optimizer.specificn, optimizer.specificu])
    vertisim_input.reset_index(drop=True, inplace=True)
    vertisim_input['id'] = run_id
    vertisim_input.to_sql('vertisim_input', conn, if_exists='append', index=False)
# Out:
# Fleet size: 50.0
# Total number of pads: 55; [19 36]
# Total number of flights: 1010.0; demand: 854.0; repositioning: 156.0
# Total energy consumption: 17989.0 kWh
# Total aircraft miles: 90900.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8455445544554455
# Fleet size: 98.0
# Total number of pads: 105; [47 58]
# Total number of flights: 1078.0; demand: 854.0; repositioning: 224.0
# Total energy consumption: 29241.0 kWh
# Total aircraft miles: 161700.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7922077922077922
# Fleet size: 44.0
# Total number of pads: 51; [18 33]
# Total number of flights: 1032.0; demand: 854.0; repositioning: 178.0
# Total energy consumption: 16512.0 kWh
# Total aircraft miles: 82560.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8275193798449613
# Fleet size: 44.0
# Total number of pads: 47; [16 31]
# Total number of flights: 1014.0; demand: 854.0; repositioning: 160.0
# Total energy consumption: 16224.0 kWh
# Total aircraft miles: 81120.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8422090729783037
# Fleet size: 29.0
# Total number of pads: 36; [12 24]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 10978.0 kWh
# Total aircraft miles: 49900.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 77.0
# Total number of pads: 77; [28 49]
# Total number of flights: 1090.0; demand: 854.0; repositioning: 236.0
# Total energy consumption: 26160.0 kWh
# Total aircraft miles: 141700.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7834862385321101
# Fleet size: 37.0
# Total number of pads: 44; [15 29]
# Total number of flights: 1020.0; demand: 854.0; repositioning: 166.0
# Total energy consumption: 14345.0 kWh
# Total aircraft miles: 71400.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8372549019607843
# Fleet size: 40.0
# Total number of pads: 50; [17 33]
# Total number of flights: 1002.0; demand: 854.0; repositioning: 148.0
# Total energy consumption: 14529.0 kWh
# Total aircraft miles: 70140.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8522954091816367
# Fleet size: 15.0
# Total number of pads: 23; [10 13]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 5988.0 kWh
# Total aircraft miles: 19960.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 22.0
# Total number of pads: 31; [12 19]
# Total number of flights: 974.0; demand: 854.0; repositioning: 120.0
# Total energy consumption: 9550.0 kWh
# Total aircraft miles: 38960.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8767967145790554
# Fleet size: 51.0
# Total number of pads: 56; [24 32]
# Total number of flights: 1104.0; demand: 854.0; repositioning: 250.0
# Total energy consumption: 19456.0 kWh
# Total aircraft miles: 99360.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7735507246376812
# Fleet size: 29.0
# Total number of pads: 37; [12 25]
# Total number of flights: 992.0; demand: 854.0; repositioning: 138.0
# Total energy consumption: 10954.0 kWh
# Total aircraft miles: 49600.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8608870967741935
# Fleet size: 53.0
# Total number of pads: 61; [22 39]
# Total number of flights: 1076.0; demand: 854.0; repositioning: 222.0
# Total energy consumption: 18978.0 kWh
# Total aircraft miles: 96840.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7936802973977695
# Fleet size: 73.0
# Total number of pads: 79; [29 50]
# Total number of flights: 1054.0; demand: 854.0; repositioning: 200.0
# Total energy consumption: 25372.0 kWh
# Total aircraft miles: 137020.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8102466793168881
# Fleet size: 22.0
# Total number of pads: 30; [11 19]
# Total number of flights: 972.0; demand: 854.0; repositioning: 118.0
# Total energy consumption: 9524.0 kWh
# Total aircraft miles: 38880.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8786008230452675
# Fleet size: 51.0
# Total number of pads: 57; [23 34]
# Total number of flights: 1084.0; demand: 854.0; repositioning: 230.0
# Total energy consumption: 19128.0 kWh
# Total aircraft miles: 97560.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7878228782287823
# Fleet size: 45.0
# Total number of pads: 61; [22 39]
# Total number of flights: 980.0; demand: 854.0; repositioning: 126.0
# Total energy consumption: 15541.0 kWh
# Total aircraft miles: 78400.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8714285714285714
# Fleet size: 25.0
# Total number of pads: 34; [13 21]
# Total number of flights: 996.0; demand: 854.0; repositioning: 142.0
# Total energy consumption: 9462.0 kWh
# Total aircraft miles: 39840.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.857429718875502
# Fleet size: 52.0
# Total number of pads: 59; [23 36]
# Total number of flights: 1092.0; demand: 854.0; repositioning: 238.0
# Total energy consumption: 19450.0 kWh
# Total aircraft miles: 98280.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.782051282051282
# Fleet size: 55.0
# Total number of pads: 66; [30 36]
# Total number of flights: 1048.0; demand: 854.0; repositioning: 194.0
# Total energy consumption: 19982.0 kWh
# Total aircraft miles: 104800.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8148854961832062
# Fleet size: 29.0
# Total number of pads: 39; [14 25]
# Total number of flights: 972.0; demand: 854.0; repositioning: 118.0
# Total energy consumption: 11054.0 kWh
# Total aircraft miles: 48600.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8786008230452675
# Fleet size: 25.0
# Total number of pads: 32; [11 21]
# Total number of flights: 1000.0; demand: 854.0; repositioning: 146.0
# Total energy consumption: 9500.0 kWh
# Total aircraft miles: 40000.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.854
# Fleet size: 53.0
# Total number of pads: 54; [18 36]
# Total number of flights: 1040.0; demand: 854.0; repositioning: 186.0
# Total energy consumption: 19892.0 kWh
# Total aircraft miles: 104000.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8211538461538461
# Fleet size: 70.0
# Total number of pads: 75; [28 47]
# Total number of flights: 1082.0; demand: 854.0; repositioning: 228.0
# Total energy consumption: 23983.0 kWh
# Total aircraft miles: 129840.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.789279112754159
# Fleet size: 45.0
# Total number of pads: 53; [18 35]
# Total number of flights: 1056.0; demand: 854.0; repositioning: 202.0
# Total energy consumption: 16760.0 kWh
# Total aircraft miles: 84480.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8087121212121212
# Fleet size: 62.0
# Total number of pads: 63; [21 42]
# Total number of flights: 1062.0; demand: 854.0; repositioning: 208.0
# Total energy consumption: 22302.0 kWh
# Total aircraft miles: 116820.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8041431261770244
# Fleet size: 15.0
# Total number of pads: 22; [ 9 13]
# Total number of flights: 984.0; demand: 854.0; repositioning: 130.0
# Total energy consumption: 6233.0 kWh
# Total aircraft miles: 19680.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8678861788617886
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 988.0; demand: 854.0; repositioning: 134.0
# Total energy consumption: 7904.0 kWh
# Total aircraft miles: 29640.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8643724696356275
# Fleet size: 68.0
# Total number of pads: 73; [27 46]
# Total number of flights: 1064.0; demand: 854.0; repositioning: 210.0
# Total energy consumption: 24072.0 kWh
# Total aircraft miles: 127680.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8026315789473685
# Fleet size: 55.0
# Total number of pads: 59; [20 39]
# Total number of flights: 1028.0; demand: 854.0; repositioning: 174.0
# Total energy consumption: 19617.0 kWh
# Total aircraft miles: 102800.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.830739299610895
# Fleet size: 15.0
# Total number of pads: 22; [ 9 13]
# Total number of flights: 986.0; demand: 854.0; repositioning: 132.0
# Total energy consumption: 6005.0 kWh
# Total aircraft miles: 19720.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8661257606490872
# Fleet size: 33.0
# Total number of pads: 42; [13 29]
# Total number of flights: 992.0; demand: 854.0; repositioning: 138.0
# Total energy consumption: 12529.0 kWh
# Total aircraft miles: 59520.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8608870967741935
# Fleet size: 79.0
# Total number of pads: 101; [39 62]
# Total number of flights: 1030.0; demand: 854.0; repositioning: 176.0
# Total energy consumption: 24912.0 kWh
# Total aircraft miles: 133900.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.829126213592233
# Fleet size: 72.0
# Total number of pads: 79; [30 49]
# Total number of flights: 1076.0; demand: 854.0; repositioning: 222.0
# Total energy consumption: 24595.0 kWh
# Total aircraft miles: 129120.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7936802973977695
# Fleet size: 29.0
# Total number of pads: 36; [11 25]
# Total number of flights: 994.0; demand: 854.0; repositioning: 140.0
# Total energy consumption: 11021.0 kWh
# Total aircraft miles: 49700.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8591549295774648
# Fleet size: 21.0
# Total number of pads: 29; [11 18]
# Total number of flights: 986.0; demand: 854.0; repositioning: 132.0
# Total energy consumption: 8129.0 kWh
# Total aircraft miles: 29580.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8661257606490872
# Fleet size: 102.0
# Total number of pads: 102; [41 61]
# Total number of flights: 1074.0; demand: 854.0; repositioning: 220.0
# Total energy consumption: 29733.0 kWh
# Total aircraft miles: 161100.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7951582867783985
# Fleet size: 92.0
# Total number of pads: 92; [36 56]
# Total number of flights: 1084.0; demand: 854.0; repositioning: 230.0
# Total energy consumption: 28439.0 kWh
# Total aircraft miles: 151760.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7878228782287823
# Fleet size: 82.0
# Total number of pads: 86; [31 55]
# Total number of flights: 1060.0; demand: 854.0; repositioning: 206.0
# Total energy consumption: 27368.0 kWh
# Total aircraft miles: 148400.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8056603773584906
# Fleet size: 25.0
# Total number of pads: 33; [12 21]
# Total number of flights: 986.0; demand: 854.0; repositioning: 132.0
# Total energy consumption: 9367.0 kWh
# Total aircraft miles: 39440.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8661257606490872
# Fleet size: 62.0
# Total number of pads: 72; [28 44]
# Total number of flights: 1068.0; demand: 854.0; repositioning: 214.0
# Total energy consumption: 22313.0 kWh
# Total aircraft miles: 117480.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.799625468164794
# Fleet size: 110.0
# Total number of pads: 110; [46 64]
# Total number of flights: 1112.0; demand: 854.0; repositioning: 258.0
# Total energy consumption: 30941.0 kWh
# Total aircraft miles: 166800.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7679856115107914
# Fleet size: 64.0
# Total number of pads: 64; [22 42]
# Total number of flights: 1086.0; demand: 854.0; repositioning: 232.0
# Total energy consumption: 22921.0 kWh
# Total aircraft miles: 119460.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7863720073664825
# Fleet size: 72.0
# Total number of pads: 77; [29 48]
# Total number of flights: 1104.0; demand: 854.0; repositioning: 250.0
# Total energy consumption: 24796.0 kWh
# Total aircraft miles: 132480.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7735507246376812
# Fleet size: 64.0
# Total number of pads: 66; [22 44]
# Total number of flights: 1066.0; demand: 854.0; repositioning: 212.0
# Total energy consumption: 22342.0 kWh
# Total aircraft miles: 117260.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.801125703564728
# Fleet size: 16.0
# Total number of pads: 25; [11 14]
# Total number of flights: 1018.0; demand: 854.0; repositioning: 164.0
# Total energy consumption: 6617.0 kWh
# Total aircraft miles: 20360.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8388998035363457
# Fleet size: 15.0
# Total number of pads: 23; [10 13]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 5988.0 kWh
# Total aircraft miles: 19960.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 90.0
# Total number of pads: 95; [38 57]
# Total number of flights: 1090.0; demand: 854.0; repositioning: 236.0
# Total energy consumption: 28122.0 kWh
# Total aircraft miles: 152600.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7834862385321101
# Fleet size: 87.0
# Total number of pads: 93; [39 54]
# Total number of flights: 1058.0; demand: 854.0; repositioning: 204.0
# Total energy consumption: 27287.0 kWh
# Total aircraft miles: 148120.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8071833648393195
# Fleet size: 85.0
# Total number of pads: 93; [37 56]
# Total number of flights: 1062.0; demand: 854.0; repositioning: 208.0
# Total energy consumption: 27452.0 kWh
# Total aircraft miles: 148680.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8041431261770244
# Fleet size: 68.0
# Total number of pads: 75; [28 47]
# Total number of flights: 1072.0; demand: 854.0; repositioning: 218.0
# Total energy consumption: 24052.0 kWh
# Total aircraft miles: 128640.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7966417910447762
# Fleet size: 33.0
# Total number of pads: 42; [13 29]
# Total number of flights: 986.0; demand: 854.0; repositioning: 132.0
# Total energy consumption: 12325.0 kWh
# Total aircraft miles: 59160.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8661257606490872
# Fleet size: 15.0
# Total number of pads: 23; [10 13]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 5988.0 kWh
# Total aircraft miles: 19960.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 22.0
# Total number of pads: 29; [10 19]
# Total number of flights: 978.0; demand: 854.0; repositioning: 124.0
# Total energy consumption: 9291.0 kWh
# Total aircraft miles: 39120.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8732106339468303
# Fleet size: 79.0
# Total number of pads: 89; [34 55]
# Total number of flights: 1074.0; demand: 854.0; repositioning: 220.0
# Total energy consumption: 25977.0 kWh
# Total aircraft miles: 139620.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7951582867783985
# Fleet size: 96.0
# Total number of pads: 96; [40 56]
# Total number of flights: 1070.0; demand: 854.0; repositioning: 216.0
# Total energy consumption: 29422.0 kWh
# Total aircraft miles: 160500.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7981308411214953
# Fleet size: 47.0
# Total number of pads: 52; [19 33]
# Total number of flights: 1044.0; demand: 854.0; repositioning: 190.0
# Total energy consumption: 16973.0 kWh
# Total aircraft miles: 83520.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8180076628352491
# Fleet size: 98.0
# Total number of pads: 103; [44 59]
# Total number of flights: 1078.0; demand: 854.0; repositioning: 224.0
# Total energy consumption: 29600.0 kWh
# Total aircraft miles: 161700.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7922077922077922
# Fleet size: 86.0
# Total number of pads: 99; [40 59]
# Total number of flights: 1056.0; demand: 854.0; repositioning: 202.0
# Total energy consumption: 27248.0 kWh
# Total aircraft miles: 147840.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8087121212121212
# Fleet size: 35.0
# Total number of pads: 43; [13 30]
# Total number of flights: 974.0; demand: 854.0; repositioning: 120.0
# Total energy consumption: 12464.0 kWh
# Total aircraft miles: 58440.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8767967145790554
# Fleet size: 23.0
# Total number of pads: 30; [11 19]
# Total number of flights: 986.0; demand: 854.0; repositioning: 132.0
# Total energy consumption: 9513.0 kWh
# Total aircraft miles: 39440.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8661257606490872
# Fleet size: 59.0
# Total number of pads: 64; [22 42]
# Total number of flights: 1090.0; demand: 854.0; repositioning: 236.0
# Total energy consumption: 21210.0 kWh
# Total aircraft miles: 109000.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7834862385321101
# Fleet size: 37.0
# Total number of pads: 44; [14 30]
# Total number of flights: 1020.0; demand: 854.0; repositioning: 166.0
# Total energy consumption: 14554.0 kWh
# Total aircraft miles: 71400.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8372549019607843
# Fleet size: 98.0
# Total number of pads: 104; [47 57]
# Total number of flights: 1084.0; demand: 854.0; repositioning: 230.0
# Total energy consumption: 29614.0 kWh
# Total aircraft miles: 162600.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7878228782287823
# Fleet size: 61.0
# Total number of pads: 64; [22 42]
# Total number of flights: 1062.0; demand: 854.0; repositioning: 208.0
# Total energy consumption: 22197.0 kWh
# Total aircraft miles: 116820.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8041431261770244
# Fleet size: 78.0
# Total number of pads: 78; [27 51]
# Total number of flights: 1058.0; demand: 854.0; repositioning: 204.0
# Total energy consumption: 25988.0 kWh
# Total aircraft miles: 137540.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8071833648393195
# Fleet size: 51.0
# Total number of pads: 57; [20 37]
# Total number of flights: 1080.0; demand: 854.0; repositioning: 226.0
# Total energy consumption: 19101.0 kWh
# Total aircraft miles: 97200.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7907407407407407
# Fleet size: 55.0
# Total number of pads: 67; [30 37]
# Total number of flights: 1044.0; demand: 854.0; repositioning: 190.0
# Total energy consumption: 19836.0 kWh
# Total aircraft miles: 104400.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8180076628352491
# Fleet size: 75.0
# Total number of pads: 81; [30 51]
# Total number of flights: 1050.0; demand: 854.0; repositioning: 196.0
# Total energy consumption: 25397.0 kWh
# Total aircraft miles: 136500.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8133333333333334
# Fleet size: 44.0
# Total number of pads: 52; [18 34]
# Total number of flights: 1014.0; demand: 854.0; repositioning: 160.0
# Total energy consumption: 16178.0 kWh
# Total aircraft miles: 81120.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8422090729783037
# Fleet size: 78.0
# Total number of pads: 86; [32 54]
# Total number of flights: 1070.0; demand: 854.0; repositioning: 216.0
# Total energy consumption: 26014.0 kWh
# Total aircraft miles: 139100.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7981308411214953
# Fleet size: 29.0
# Total number of pads: 36; [12 24]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 10978.0 kWh
# Total aircraft miles: 49900.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 99.0
# Total number of pads: 108; [50 58]
# Total number of flights: 1082.0; demand: 854.0; repositioning: 228.0
# Total energy consumption: 29402.0 kWh
# Total aircraft miles: 162300.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.789279112754159
# Fleet size: 37.0
# Total number of pads: 46; [14 32]
# Total number of flights: 980.0; demand: 854.0; repositioning: 126.0
# Total energy consumption: 13720.0 kWh
# Total aircraft miles: 68600.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8714285714285714
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 982.0; demand: 854.0; repositioning: 128.0
# Total energy consumption: 7856.0 kWh
# Total aircraft miles: 29460.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.869653767820774
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 988.0; demand: 854.0; repositioning: 134.0
# Total energy consumption: 7904.0 kWh
# Total aircraft miles: 29640.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8643724696356275
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 982.0; demand: 854.0; repositioning: 128.0
# Total energy consumption: 7856.0 kWh
# Total aircraft miles: 29460.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.869653767820774
# Fleet size: 40.0
# Total number of pads: 46; [15 31]
# Total number of flights: 1002.0; demand: 854.0; repositioning: 148.0
# Total energy consumption: 14398.0 kWh
# Total aircraft miles: 70140.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8522954091816367
# Fleet size: 70.0
# Total number of pads: 73; [25 48]
# Total number of flights: 1074.0; demand: 854.0; repositioning: 220.0
# Total energy consumption: 23820.0 kWh
# Total aircraft miles: 128880.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7951582867783985
# Fleet size: 33.0
# Total number of pads: 42; [13 29]
# Total number of flights: 978.0; demand: 854.0; repositioning: 124.0
# Total energy consumption: 12600.0 kWh
# Total aircraft miles: 58680.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8732106339468303
# Fleet size: 29.0
# Total number of pads: 39; [14 25]
# Total number of flights: 970.0; demand: 854.0; repositioning: 116.0
# Total energy consumption: 10914.0 kWh
# Total aircraft miles: 48500.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8804123711340206
# Fleet size: 51.0
# Total number of pads: 57; [20 37]
# Total number of flights: 1078.0; demand: 854.0; repositioning: 224.0
# Total energy consumption: 19185.0 kWh
# Total aircraft miles: 97020.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7922077922077922
# Fleet size: 15.0
# Total number of pads: 23; [10 13]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 5988.0 kWh
# Total aircraft miles: 19960.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 29.0
# Total number of pads: 35; [12 23]
# Total number of flights: 1016.0; demand: 854.0; repositioning: 162.0
# Total energy consumption: 11306.0 kWh
# Total aircraft miles: 50800.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8405511811023622
# Fleet size: 97.0
# Total number of pads: 97; [40 57]
# Total number of flights: 1074.0; demand: 854.0; repositioning: 220.0
# Total energy consumption: 29511.0 kWh
# Total aircraft miles: 161100.0 mi
# Total revenue aircraft miles: 128100.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7951582867783985
# Fleet size: 65.0
# Total number of pads: 68; [24 44]
# Total number of flights: 1098.0; demand: 854.0; repositioning: 244.0
# Total energy consumption: 22790.0 kWh
# Total aircraft miles: 120780.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7777777777777778
# Fleet size: 57.0
# Total number of pads: 62; [24 38]
# Total number of flights: 1084.0; demand: 854.0; repositioning: 230.0
# Total energy consumption: 20826.0 kWh
# Total aircraft miles: 108400.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7878228782287823
# Fleet size: 67.0
# Total number of pads: 68; [24 44]
# Total number of flights: 1060.0; demand: 854.0; repositioning: 206.0
# Total energy consumption: 23653.0 kWh
# Total aircraft miles: 127200.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8056603773584906
# Fleet size: 15.0
# Total number of pads: 23; [10 13]
# Total number of flights: 998.0; demand: 854.0; repositioning: 144.0
# Total energy consumption: 5988.0 kWh
# Total aircraft miles: 19960.0 mi
# Total revenue aircraft miles: 17080.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8557114228456913
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 988.0; demand: 854.0; repositioning: 134.0
# Total energy consumption: 7904.0 kWh
# Total aircraft miles: 29640.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8643724696356275
# Fleet size: 34.0
# Total number of pads: 44; [15 29]
# Total number of flights: 964.0; demand: 854.0; repositioning: 110.0
# Total energy consumption: 12050.0 kWh
# Total aircraft miles: 57840.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8858921161825726
# Fleet size: 59.0
# Total number of pads: 65; [25 40]
# Total number of flights: 1084.0; demand: 854.0; repositioning: 230.0
# Total energy consumption: 21091.0 kWh
# Total aircraft miles: 108400.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7878228782287823
# Fleet size: 88.0
# Total number of pads: 107; [30 77]
# Total number of flights: 922.0; demand: 854.0; repositioning: 68.0
# Total energy consumption: 24005.0 kWh
# Total aircraft miles: 129080.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.9262472885032538
# Fleet size: 44.0
# Total number of pads: 58; [23 35]
# Total number of flights: 1028.0; demand: 854.0; repositioning: 174.0
# Total energy consumption: 16323.0 kWh
# Total aircraft miles: 82240.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.830739299610895
# Fleet size: 35.0
# Total number of pads: 43; [13 30]
# Total number of flights: 974.0; demand: 854.0; repositioning: 120.0
# Total energy consumption: 12466.0 kWh
# Total aircraft miles: 58440.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8767967145790554
# Fleet size: 55.0
# Total number of pads: 66; [27 39]
# Total number of flights: 1060.0; demand: 854.0; repositioning: 206.0
# Total energy consumption: 20376.0 kWh
# Total aircraft miles: 106000.0 mi
# Total revenue aircraft miles: 85400.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8056603773584906
# Fleet size: 40.0
# Total number of pads: 49; [18 31]
# Total number of flights: 1028.0; demand: 854.0; repositioning: 174.0
# Total energy consumption: 14733.0 kWh
# Total aircraft miles: 71960.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.830739299610895
# Fleet size: 25.0
# Total number of pads: 34; [13 21]
# Total number of flights: 986.0; demand: 854.0; repositioning: 132.0
# Total energy consumption: 9476.0 kWh
# Total aircraft miles: 39440.0 mi
# Total revenue aircraft miles: 34160.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8661257606490872
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 988.0; demand: 854.0; repositioning: 134.0
# Total energy consumption: 7904.0 kWh
# Total aircraft miles: 29640.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8643724696356275
# Fleet size: 60.0
# Total number of pads: 60; [24 36]
# Total number of flights: 1058.0; demand: 854.0; repositioning: 204.0
# Total energy consumption: 21885.0 kWh
# Total aircraft miles: 116380.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8071833648393195
# Fleet size: 40.0
# Total number of pads: 51; [17 34]
# Total number of flights: 992.0; demand: 854.0; repositioning: 138.0
# Total energy consumption: 14363.0 kWh
# Total aircraft miles: 69440.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8608870967741935
# Fleet size: 21.0
# Total number of pads: 28; [10 18]
# Total number of flights: 994.0; demand: 854.0; repositioning: 140.0
# Total energy consumption: 8103.0 kWh
# Total aircraft miles: 29820.0 mi
# Total revenue aircraft miles: 25620.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8591549295774648
# Fleet size: 85.0
# Total number of pads: 88; [30 58]
# Total number of flights: 1064.0; demand: 854.0; repositioning: 210.0
# Total energy consumption: 27302.0 kWh
# Total aircraft miles: 148960.0 mi
# Total revenue aircraft miles: 119560.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8026315789473685
# Fleet size: 71.0
# Total number of pads: 79; [30 49]
# Total number of flights: 1064.0; demand: 854.0; repositioning: 210.0
# Total energy consumption: 24274.0 kWh
# Total aircraft miles: 127680.0 mi
# Total revenue aircraft miles: 102480.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8026315789473685
# Fleet size: 29.0
# Total number of pads: 37; [12 25]
# Total number of flights: 970.0; demand: 854.0; repositioning: 116.0
# Total energy consumption: 11110.0 kWh
# Total aircraft miles: 48500.0 mi
# Total revenue aircraft miles: 42700.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8804123711340206
# Fleet size: 36.0
# Total number of pads: 44; [13 31]
# Total number of flights: 962.0; demand: 854.0; repositioning: 108.0
# Total energy consumption: 13827.0 kWh
# Total aircraft miles: 67340.0 mi
# Total revenue aircraft miles: 59780.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8877338877338877
# Fleet size: 64.0
# Total number of pads: 64; [22 42]
# Total number of flights: 1094.0; demand: 854.0; repositioning: 240.0
# Total energy consumption: 23182.0 kWh
# Total aircraft miles: 120340.0 mi
# Total revenue aircraft miles: 93940.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7806215722120659
# Fleet size: 33.0
# Total number of pads: 42; [13 29]
# Total number of flights: 966.0; demand: 854.0; repositioning: 112.0
# Total energy consumption: 12558.0 kWh
# Total aircraft miles: 57960.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8840579710144928
# Fleet size: 47.0
# Total number of pads: 54; [18 36]
# Total number of flights: 1048.0; demand: 854.0; repositioning: 194.0
# Total energy consumption: 16974.0 kWh
# Total aircraft miles: 83840.0 mi
# Total revenue aircraft miles: 68320.0
# Ratio of revenue aircraft miles to aircraft miles: 0.8148854961832062
# Fleet size: 76.0
# Total number of pads: 85; [36 49]
# Total number of flights: 1070.0; demand: 854.0; repositioning: 216.0
# Total energy consumption: 25719.0 kWh
# Total aircraft miles: 139100.0 mi
# Total revenue aircraft miles: 111020.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7981308411214953
# Fleet size: 53.0
# Total number of pads: 57; [22 35]
# Total number of flights: 1096.0; demand: 854.0; repositioning: 242.0
# Total energy consumption: 19180.0 kWh
# Total aircraft miles: 98640.0 mi
# Total revenue aircraft miles: 76860.0
# Ratio of revenue aircraft miles to aircraft miles: 0.7791970802919708
# Fleet size: 35.0
# Total number of pads: 45; [15 30]
# Total number of flights: 976.0; demand: 854.0; repositioning: 122.0
# Total energy consumption: 12341.0 kWh
# Total aircraft miles: 58560.0 mi
# Total revenue aircraft miles: 51240.0
# Ratio of revenue aircraft miles to aircraft miles: 0.875

# %%
conn = sqlite3.connect('wind_variation_result.sqlite')
query = """
SELECT *
FROM op_summary_statistics
"""
df = pd.read_sql_query(query, conn)

# %%
df.sort_values('id')
# Out:
#      fleet_size  pads_at_SFO  pads_at_SJC  number_of_repositioning_flights  \
# 67         55.0         30.0         37.0                            190.0
# 19         55.0         30.0         36.0                            194.0
# 22         53.0         18.0         36.0                            186.0
# 86         57.0         24.0         38.0                            230.0
# 29         55.0         20.0         39.0                            174.0
# ..          ...          ...          ...                              ...
# 110        53.0         22.0         35.0                            242.0
# 66         51.0         20.0         37.0                            226.0
# 10         51.0         24.0         32.0                            250.0
# 15         51.0         23.0         34.0                            230.0
# 81         51.0         20.0         37.0                            224.0
#
#                    id
# 67   dist_100_per_500
# 19   dist_100_per_600
# 22   dist_100_per_700
# 86   dist_100_per_800
# 29   dist_100_per_900
# ..                ...
# 110   dist_90_per_800
# 66    dist_90_per_900
# 10    dist_90_per_950
# 15    dist_90_per_990
# 81    dist_90_per_995
#
# [112 rows x 5 columns]
